# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushbooyadav04/Weather_Forecast/blob/main/Weather_datasheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c8f57881-a731-43e5-a212-e878294eb3e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8f57881-a731-43e5-a212-e878294eb3e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Weather_data.xlsx to Weather_data.xlsx

# %%
import io
df= pd.read_excel(io.BytesIO(uploaded["Weather_data.xlsx"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-02531626becd> in <module>()
#       1 import io
# ----> 2 df= pd.read_excel(io.BytesIO(uploaded["Weather_data.xlsx"]))
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#                 Date/Time  Temp_C  ...  Press_kPa               Weather
# 0     2012-01-01 00:00:00    -1.8  ...     101.24                   Fog
# 1     2012-01-01 01:00:00    -1.8  ...     101.24                   Fog
# 2     2012-01-01 02:00:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3     2012-01-01 03:00:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4     2012-01-01 04:00:00    -1.5  ...     101.23                   Fog
# ...                   ...     ...  ...        ...                   ...
# 8779     12/31/2012 19:00     0.1  ...     100.13                  Snow
# 8780     12/31/2012 20:00     0.2  ...     100.03                  Snow
# 8781     12/31/2012 21:00    -0.5  ...      99.95                  Snow
# 8782     12/31/2012 22:00    -0.2  ...      99.91                  Snow
# 8783     12/31/2012 23:00     0.0  ...      99.89                  Snow
#
# [8784 rows x 8 columns]

# %%
df.head()
# Out:
#              Date/Time  Temp_C  ...  Press_kPa               Weather
# 0  2012-01-01 00:00:00    -1.8  ...     101.24                   Fog
# 1  2012-01-01 01:00:00    -1.8  ...     101.24                   Fog
# 2  2012-01-01 02:00:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  2012-01-01 03:00:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  2012-01-01 04:00:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df["Weather"].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df["Weather"].nunique()
# Out:
# 50

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df["Weather"].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df.head(2)
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather
# 0  2012-01-01 00:00:00    -1.8  ...     101.24      Fog
# 1  2012-01-01 01:00:00    -1.8  ...     101.24      Fog
#
# [2 rows x 8 columns]

# %%
df["Wind Speed_km/h"].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
import io
df= pd.read_excel(io.BytesIO(uploaded["Weather_data.xlsx"])) 
df
# Out:
#      <input type="file" id="files-8a9b6533-5280-46cc-b3e1-fd490f3d73da" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a9b6533-5280-46cc-b3e1-fd490f3d73da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Weather_data.xlsx to Weather_data.xlsx
#                 Date/Time  Temp_C  ...  Press_kPa               Weather
# 0     2012-01-01 00:00:00    -1.8  ...     101.24                   Fog
# 1     2012-01-01 01:00:00    -1.8  ...     101.24                   Fog
# 2     2012-01-01 02:00:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3     2012-01-01 03:00:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4     2012-01-01 04:00:00    -1.5  ...     101.23                   Fog
# ...

# %%
df.head(2)
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather
# 0  2012-01-01 00:00:00    -1.8  ...     101.24      Fog
# 1  2012-01-01 01:00:00    -1.8  ...     101.24      Fog
#
# [2 rows x 8 columns]

# %%
df[df.Weather == "Clear"]
# Out:
#                 Date/Time  Temp_C  ...  Press_kPa  Weather
# 67    2012-03-01 19:00:00   -16.9  ...     101.74    Clear
# 114   2012-05-01 18:00:00    -7.1  ...     100.71    Clear
# 115   2012-05-01 19:00:00    -9.2  ...     100.80    Clear
# 116   2012-05-01 20:00:00    -9.8  ...     100.83    Clear
# 117   2012-05-01 21:00:00    -9.0  ...     100.83    Clear
# ...                   ...     ...  ...        ...      ...
# 8646      12/26/2012 6:00   -13.4  ...     102.47    Clear
# 8698     12/28/2012 10:00    -6.1  ...     101.27    Clear
# 8713      12/29/2012 1:00   -11.9  ...     101.31    Clear
# 8714      12/29/2012 2:00   -11.8  ...     101.33    Clear
# 8756     12/30/2012 20:00   -13.8  ...     101.52    Clear
#
# [1326 rows x 8 columns]

# %%
df.head(2)
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather
# 0  2012-01-01 00:00:00    -1.8  ...     101.24      Fog
# 1  2012-01-01 01:00:00    -1.8  ...     101.24      Fog
#
# [2 rows x 8 columns]

# %%
df.groupby("Weather").get_group("Clear")
# Out:
#                 Date/Time  Temp_C  ...  Press_kPa  Weather
# 67    2012-03-01 19:00:00   -16.9  ...     101.74    Clear
# 114   2012-05-01 18:00:00    -7.1  ...     100.71    Clear
# 115   2012-05-01 19:00:00    -9.2  ...     100.80    Clear
# 116   2012-05-01 20:00:00    -9.8  ...     100.83    Clear
# 117   2012-05-01 21:00:00    -9.0  ...     100.83    Clear
# ...                   ...     ...  ...        ...      ...
# 8646      12/26/2012 6:00   -13.4  ...     102.47    Clear
# 8698     12/28/2012 10:00    -6.1  ...     101.27    Clear
# 8713      12/29/2012 1:00   -11.9  ...     101.31    Clear
# 8714      12/29/2012 2:00   -11.8  ...     101.33    Clear
# 8756     12/30/2012 20:00   -13.8  ...     101.52    Clear
#
# [1326 rows x 8 columns]

# %%
df.head(2)
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather
# 0  2012-01-01 00:00:00    -1.8  ...     101.24      Fog
# 1  2012-01-01 01:00:00    -1.8  ...     101.24      Fog
#
# [2 rows x 8 columns]

# %%
df[df["Wind Speed_km/h"] == 4]
# Out:
#                 Date/Time  Temp_C  ...  Press_kPa       Weather
# 0     2012-01-01 00:00:00    -1.8  ...     101.24           Fog
# 1     2012-01-01 01:00:00    -1.8  ...     101.24           Fog
# 96    2012-05-01 00:00:00    -8.8  ...     100.32          Snow
# 101   2012-05-01 05:00:00    -7.0  ...     100.19          Snow
# 146   2012-07-01 02:00:00    -8.1  ...     100.15        Cloudy
# ...                   ...     ...  ...        ...           ...
# 8768      12/31/2012 8:00    -8.6  ...     101.14  Snow Showers
# 8769      12/31/2012 9:00    -8.1  ...     101.09          Snow
# 8770     12/31/2012 10:00    -7.4  ...     101.05      Snow,Fog
# 8772     12/31/2012 12:00    -5.8  ...     100.78          Snow
# 8773     12/31/2012 13:00    -4.6  ...     100.63          Snow
#
# [474 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df.head(2)
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather
# 0  2012-01-01 00:00:00    -1.8  ...     101.24      Fog
# 1  2012-01-01 01:00:00    -1.8  ...     101.24      Fog
#
# [2 rows x 8 columns]

# %%
df.rename(columns ={"Weather" :"Weather condition"}, inplace=True)

# %%
df.head(2)
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather condition
# 0  2012-01-01 00:00:00    -1.8  ...     101.24                Fog
# 1  2012-01-01 01:00:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
df.head(2)
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather condition
# 0  2012-01-01 00:00:00    -1.8  ...     101.24                Fog
# 1  2012-01-01 01:00:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
df.Visibility_km.mean()
# Out:
# 27.66444672131151

# %%
df.Press_kPa.std()
# Out:
# 0.8440047459486474

# %%
df['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %%
df["Weather condition"].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df[df["Weather condition"]=="Snow"]
# Out:
#                 Date/Time  Temp_C  ...  Press_kPa  Weather condition
# 55    2012-03-01 07:00:00   -14.0  ...     100.95               Snow
# 84    2012-04-01 12:00:00   -13.7  ...     101.25               Snow
# 86    2012-04-01 14:00:00   -11.3  ...     100.97               Snow
# 87    2012-04-01 15:00:00   -10.2  ...     100.89               Snow
# 88    2012-04-01 16:00:00    -9.4  ...     100.79               Snow
# ...                   ...     ...  ...        ...                ...
# 8779     12/31/2012 19:00     0.1  ...     100.13               Snow
# 8780     12/31/2012 20:00     0.2  ...     100.03               Snow
# 8781     12/31/2012 21:00    -0.5  ...      99.95               Snow
# 8782     12/31/2012 22:00    -0.2  ...      99.91               Snow
# 8783     12/31/2012 23:00     0.0  ...      99.89               Snow
#
# [390 rows x 8 columns]

# %%
df[df["Weather condition"].str.contains('Snow')].tail(50)
# Out:
#              Date/Time  Temp_C  ...  Press_kPa      Weather condition
# 8680  12/27/2012 16:00    -4.5  ...     100.44      Snow,Blowing Snow
# 8681  12/27/2012 17:00    -4.2  ...     100.47      Snow,Blowing Snow
# 8682  12/27/2012 18:00    -4.0  ...     100.49      Snow,Blowing Snow
# 8683  12/27/2012 19:00    -3.9  ...     100.52      Snow,Blowing Snow
# 8684  12/27/2012 20:00    -3.7  ...     100.58                   Snow
# 8685  12/27/2012 21:00    -3.7  ...     100.62  Freezing Drizzle,Snow
# 8686  12/27/2012 22:00    -3.8  ...     100.65  Freezing Drizzle,Snow
# 8687  12/27/2012 23:00    -4.0  ...     100.70                   Snow
# 8688   12/28/2012 0:00    -4.2  ...     100.78  Freezing Drizzle,Snow
# 8689   12/28/2012 1:00    -4.4  ...     100.83  Freezing Drizzle,Snow
# 8690   12/28/2012 2:00    -4.3  ...     100.93  Freezing Drizzle,Snow
# 8691   12/28/2012 3:00    -4.6  ...     101.01                   Snow
# ...

# %%
df.head(2)
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather condition
# 0  2012-01-01 00:00:00    -1.8  ...     101.24                Fog
# 1  2012-01-01 01:00:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
df[(df["Wind Speed_km/h"] > 24) & (df["Visibility_km"] == 25)]
# Out:
#                 Date/Time  Temp_C  ...  Press_kPa  Weather condition
# 23    2012-01-01 23:00:00     5.3  ...      99.31             Cloudy
# 24    2012-02-01 00:00:00     5.2  ...      99.26       Rain Showers
# 25    2012-02-01 01:00:00     4.6  ...      99.26             Cloudy
# 26    2012-02-01 02:00:00     3.9  ...      99.26      Mostly Cloudy
# 27    2012-02-01 03:00:00     3.7  ...      99.30      Mostly Cloudy
# ...                   ...     ...  ...        ...                ...
# 8705     12/28/2012 17:00    -8.6  ...     101.34       Mainly Clear
# 8753     12/30/2012 17:00   -12.1  ...     101.26       Mainly Clear
# 8755     12/30/2012 19:00   -13.4  ...     101.47       Mainly Clear
# 8759     12/30/2012 23:00   -12.1  ...     101.52      Mostly Cloudy
# 8760      12/31/2012 0:00   -11.1  ...     101.51             Cloudy
#
# [308 rows x 8 columns]

# %%
df.head(2)
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather condition
# 0  2012-01-01 00:00:00    -1.8  ...     101.24                Fog
# 1  2012-01-01 01:00:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
df.groupby("Weather condition").mean()
# Out:
#                                             Temp_C  ...   Press_kPa
# Weather condition                                   ...
# Clear                                     6.825716  ...  101.587443
# Cloudy                                    7.970544  ...  100.911441
# Drizzle                                   7.353659  ...  100.435366
# Drizzle,Fog                               8.067500  ...  100.786625
# Drizzle,Ice Pellets,Fog                   0.400000  ...  100.790000
# Drizzle,Snow                              1.050000  ...  100.890000
# Drizzle,Snow,Fog                          0.693333  ...   99.281333
# Fog                                       4.303333  ...  101.184067
# Freezing Drizzle                         -5.657143  ...  100.202857
# Freezing Drizzle,Fog                     -2.533333  ...  100.441667
# Freezing Drizzle,Haze                    -5.433333  ...  100.316667
# Freezing Drizzle,Snow                    -5.109091  ...  100.520909
# ...

# %%
df.head(2)
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather condition
# 0  2012-01-01 00:00:00    -1.8  ...     101.24                Fog
# 1  2012-01-01 01:00:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %%
df.groupby("Weather condition").min()
# Out:
#                                          Temp_C  ...  Press_kPa
# Weather condition                                ...
# Clear                                     -23.3  ...      99.52
# Cloudy                                    -21.4  ...      98.39
# Drizzle                                     1.1  ...      97.84
# Drizzle,Fog                                 0.0  ...      98.65
# Drizzle,Ice Pellets,Fog                     0.4  ...     100.79
# Drizzle,Snow                                0.9  ...     100.63
# Drizzle,Snow,Fog                            0.3  ...      97.79
# Fog                                       -16.0  ...      98.31
# Freezing Drizzle                           -9.0  ...      98.44
# Freezing Drizzle,Fog                       -6.4  ...      98.74
# Freezing Drizzle,Haze                      -5.8  ...     100.28
# Freezing Drizzle,Snow                      -8.3  ...      99.19
# Freezing Fog                              -19.0  ...     101.97
# ...

# %%
df.groupby("Weather condition").max()
# Out:
#                                          Temp_C  ...  Press_kPa
# Weather condition                                ...
# Clear                                      32.8  ...     103.63
# Cloudy                                     30.5  ...     103.65
# Drizzle                                    18.8  ...     101.56
# Drizzle,Fog                                19.9  ...     102.07
# Drizzle,Ice Pellets,Fog                     0.4  ...     100.79
# Drizzle,Snow                                1.2  ...     101.15
# Drizzle,Snow,Fog                            1.1  ...     100.15
# Fog                                        20.8  ...     103.04
# Freezing Drizzle                           -2.3  ...     101.02
# Freezing Drizzle,Fog                       -0.3  ...     101.27
# Freezing Drizzle,Haze                      -5.0  ...     100.36
# Freezing Drizzle,Snow                      -3.3  ...     101.18
# Freezing Fog                               -0.1  ...     102.85
# ...
